# %% [markdown]
# # Scryfall Analysis - Cube Structure

# %% [markdown]
# __Objective:__ Connect to publicly available data on Scryfall through their REST API to identify patterns set design.

# %%
import datetime
print("Script last ran on", datetime.datetime.today().strftime("%m/%d/%Y"))

# %%
# libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import requests
from selenium import webdriver

# %%
# open browser and go to scryfall
driver = webdriver.Chrome()
driver.get("https://scryfall.com/docs/api/bulk-data")

# retrieve the most recent json file containing 'Default Cards'
default_cards_href = driver.find_element_by_css_selector('#main > div > div.reference-doc-content > div > table:nth-child(7) > tbody > tr:nth-child(5) > td:nth-child(2) > a').get_attribute('href')

# retrieve the most recent json file containing 'All Cards'
all_cards_href = driver.find_element_by_css_selector('#main > div > div.reference-doc-content > div > table:nth-child(7) > tbody > tr:nth-child(7) > td:nth-child(2) > a').get_attribute('href')

print("HREF for 'Default Cards' Bulk Dataset:\n", default_cards_href, "\n")
print("HREF for 'All Cards' Bulk Dataset:\n", all_cards_href)
# Out:
# HREF for 'Default Cards' Bulk Dataset:
#  https://c2.scryfall.com/file/scryfall-bulk/default-cards/default-cards-20210602090332.json
#
# HREF for 'All Cards' Bulk Dataset:
#  https://c2.scryfall.com/file/scryfall-bulk/all-cards/all-cards-20210602091452.json

# %%
driver.quit()
# df = pd.read_json(default_cards_href)
df = pd.read_json(default_cards_href)

# %%
print("Shape of df (rows, columns): ", df.shape)
print("Columns Names\n", list(df.columns), "\n")
df.head()
# Out:
# Shape of df (rows, columns):  (60197, 78)
# Columns Names
#  ['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'mtgo_foil_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang', 'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line', 'oracle_text', 'power', 'toughness', 'colors', 'color_identity', 'keywords', 'legalities', 'games', 'reserved', 'foil', 'nonfoil', 'oversized', 'promo', 'reprint', 'variation', 'set', 'set_name', 'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri', 'rulings_uri', 'prints_search_uri', 'collector_number', 'digital', 'rarity', 'flavor_text', 'card_back_id', 'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame', 'full_art', 'textless', 'booster', 'story_spotlight', 'edhrec_rank', 'prices', 'related_uris', 'all_parts', 'promo_types', 'arena_id', 'preview', 'produced_mana', 'watermark', 'frame_effects', 'loyalty', 'printed_name', 'card_faces', 'color_indicator', 'life_modifier', 'hand_modifier', 'printed_type_line', 'printed_text', 'content_warning', 'variation_of', 'flavor_name']
#   object                                    id  \
# 0   card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1   card  00006596-1166-4a79-8443-ca9f82e6db4e
# 2   card  0000a54c-a511-4925-92dc-01b937f9afad
# 3   card  0000cd57-91fe-411f-b798-646e965eec37
# 4   card  00012bd8-ed68-4978-a22d-f450c8a6e048
#
#                               oracle_id multiverse_ids  mtgo_id  mtgo_foil_id  \
# 0  44623693-51d6-49ad-8cd7-140505caf02f       [109722]  25527.0       25528.0
# 1  8ae3562f-28b7-4462-96ed-be0cf7052ccc       [189637]  34586.0       34587.0
# 2  dc4e2134-f0c2-49aa-9ea3-ebf83af1445c             []      NaN           NaN
# 3  9f0d82ae-38bf-45d8-8cda-982b6ead1d72       [435231]  65170.0       65171.0
# 4  5aa12aff-db3c-4be5-822b-3afdf536b33e         [1278]      NaN           NaN
#
#    tcgplayer_id  cardmarket_id           name lang  ... printed_name  \
# 0       14240.0        13850.0    Fury Sliver   en  ...          NaN
# 1       33347.0        21851.0  Kor Outfitter   en  ...          NaN
# 2       98659.0            NaN         Spirit   en  ...          NaN
# 3      145764.0       301766.0  Siren Lookout   en  ...          NaN
# 4        1623.0         5664.0            Web   en  ...          NaN
#
#   card_faces color_indicator life_modifier  hand_modifier printed_type_line  \
# 0        NaN             NaN           NaN            NaN               NaN
# 1        NaN             NaN           NaN            NaN               NaN
# 2        NaN             NaN           NaN            NaN               NaN
# 3        NaN             NaN           NaN            NaN               NaN
# 4        NaN             NaN           NaN            NaN               NaN
#
#   printed_text content_warning  variation_of flavor_name
# 0          NaN             NaN           NaN         NaN
# 1          NaN             NaN           NaN         NaN
# 2          NaN             NaN           NaN         NaN
# 3          NaN             NaN           NaN         NaN
# 4          NaN             NaN           NaN         NaN
#
# [5 rows x 78 columns]

# %%
# tidy dataframe
cols = ['name', 'mana_cost', 'cmc', 'type_line', 'oracle_text', 'power', 'toughness', 'colors', 'color_identity', 'keywords', 'set', 'set_name', 'rarity', 'edhrec_rank', 'produced_mana', 'printed_name', 'printed_text', 'legalities', 'lang']
pioneer_sets = ['Strixhaven: School of Mages', 'Kaldheim', 'Zendikar Rising', 'Core 2021', 'Ikoria Lair of Behemoths', 'Theros Beyond Death', 'Throne of Eldraine', 'Core Set 2020', 
                'War of the Spark', 'Ravnica Allegiance', 'Guilds of Ravnica', 'Core Set 2019', 'Dominaria', 'Rivals of Ixalan', 'Ixalan', 'Hour of Devastation', 
                'Amonkhet', 'Aether Revolt', 'Kaladesh', 'Eldritch Moon', 'Shadows over Innistrad', 'Oath of the Gatewatch', 'Battle for Zendikar', 'Magic Origins', 
                'Dragons of Tarkir', 'Fate Reforged', 'Khans of Tarkir', 'Magic 2015', 'Journey into Nyx', 'Born of the Gods', 'Theros', 'Magic 2014', 
                "Dragon's Maze", 'Gatecrash', 'Return to Ravnica']

pioneer = df[cols]

#pioneer = pioneer[pioneer['legalities'].astype(str).str.contains("'pioneer': 'legal'")] # take only cards from pioneer onwards
pioneer = pioneer[pioneer['set_name'].isin(pioneer_sets)]
pioneer = pioneer[(pioneer['rarity'] == 'common') & (~pioneer['type_line'].str.contains('Land')) &
                 (pioneer['lang'] == 'en')] # filter for commons that aren't lands
pioneer
# Out:
#                         name  mana_cost  cmc                   type_line  \
# 3              Siren Lookout     {2}{U}  3.0     Creature — Siren Pirate
# 21                    Charge        {W}  1.0                     Instant
# 31     Destructive Tampering     {2}{R}  3.0                     Sorcery
# 58                     Shock        {R}  1.0                     Instant
# 74      Initiate's Companion     {1}{G}  2.0              Creature — Cat
# ...                      ...        ...  ...                         ...
# 60116            Cobblebrute     {3}{R}  4.0        Creature — Elemental
# 60123               Root Out     {2}{G}  3.0                     Sorcery
# 60153      Thrashing Mossdog     {3}{G}  4.0        Creature — Plant Dog
# 60180            Hold at Bay     {1}{W}  2.0                     Instant
# 60196    Exultant Skymarcher  {1}{W}{W}  3.0  Creature — Vampire Soldier
#
#                                              oracle_text power toughness  \
# 3      Flying\nWhen Siren Lookout enters the battlefi...     1         2
# 21     Creatures you control get +1/+1 until end of t...   NaN       NaN
# 31     Choose one —\n• Destroy target artifact.\n• Cr...   NaN       NaN
# 58                   Shock deals 2 damage to any target.   NaN       NaN
# 74     Whenever Initiate's Companion deals combat dam...     3         1
# ...                                                  ...   ...       ...
# 60116                                                        5         2
# 60123  Destroy target artifact or enchantment.\nInves...   NaN       NaN
# 60153  Reach (This creature can block creatures with ...     3         3
# 60180  Prevent the next 7 damage that would be dealt ...   NaN       NaN
# 60196                                             Flying     2         3
#
#       colors color_identity           keywords  set                set_name  \
# 3        [U]            [U]  [Flying, Explore]  xln                  Ixalan
# 21       [W]            [W]                 []  dom               Dominaria
# 31       [R]            [R]                 []  aer           Aether Revolt
# 58       [R]            [R]                 []  aer           Aether Revolt
# 74       [G]            [G]                 []  akh                Amonkhet
# ...      ...            ...                ...  ...                     ...
# 60116    [R]            [R]                 []  ori           Magic Origins
# 60123    [G]            [G]      [Investigate]  soi  Shadows over Innistrad
# 60153    [G]            [G]  [Scavenge, Reach]  dgm           Dragon's Maze
# 60180    [W]            [W]                 []  bng        Born of the Gods
# 60196    [W]            [W]           [Flying]  rix        Rivals of Ixalan
#
#        rarity  edhrec_rank produced_mana printed_name printed_text  \
# 3      common       9422.0           NaN          NaN          NaN
# 21     common      11706.0           NaN          NaN          NaN
# 31     common      10483.0           NaN          NaN          NaN
# 58     common       2895.0           NaN          NaN          NaN
# 74     common       9566.0           NaN          NaN          NaN
# ...       ...          ...           ...          ...          ...
# 60116  common      17480.0           NaN          NaN          NaN
# 60123  common       9470.0           NaN          NaN          NaN
# 60153  common      14324.0           NaN          NaN          NaN
# 60180  common      16812.0           NaN          NaN          NaN
# 60196  common      14026.0           NaN          NaN          NaN
#
#                                               legalities lang
# 3      {'standard': 'not_legal', 'future': 'not_legal...   en
# 21     {'standard': 'not_legal', 'future': 'not_legal...   en
# 31     {'standard': 'legal', 'future': 'legal', 'hist...   en
# 58     {'standard': 'legal', 'future': 'legal', 'hist...   en
# 74     {'standard': 'not_legal', 'future': 'not_legal...   en
# ...                                                  ...  ...
# 60116  {'standard': 'not_legal', 'future': 'not_legal...   en
# 60123  {'standard': 'not_legal', 'future': 'not_legal...   en
# 60153  {'standard': 'not_legal', 'future': 'not_legal...   en
# 60180  {'standard': 'not_legal', 'future': 'not_legal...   en
# 60196  {'standard': 'not_legal', 'future': 'not_legal...   en
#
# [3086 rows x 19 columns]

# %% [markdown]
# ## Summary Statistics by Set

# %%
card_type_breakdown = pioneer.groupby('set_name').size().reset_index(name = 'commons') # number of commons

card_types = ['Creature', 'Enchantment', 'Instant', 'Sorcery', 'Artifact']
for card_type in card_types:
    new_df = pioneer[pioneer['type_line'].str.contains(card_type)].groupby('set_name').size().reset_index(name = card_type + "s")
    card_type_breakdown = card_type_breakdown.merge(new_df, how = 'left', on = 'set_name')

print('\nCard Type Breakdown\n')
card_type_breakdown = card_type_breakdown.replace(np.nan, 0)
card_type_breakdown
# Out:
# Card Type Breakdown
#                        set_name  commons  Creatures  Enchantments  Instants  \
# 0                 Aether Revolt       75         40           4.0        12
# 1                      Amonkhet       99         55           9.0        24
# 2           Battle for Zendikar       95         55           3.0        21
# 3              Born of the Gods       60         32          14.0        12
# 4                 Core Set 2019      113         66           7.0        23
# 5                 Core Set 2020      141         90          11.0        22
# 6                     Dominaria      103         56           5.0        24
# 7                 Dragon's Maze       60         30           2.0         8
# 8             Dragons of Tarkir      100         56           5.0        25
# 9                 Eldritch Moon       75         40           7.0        13
# 10                Fate Reforged       60         28           6.0        18
# 11                    Gatecrash       96         49          10.0        22
# 12            Guilds of Ravnica      102         60           6.0        16
# 13          Hour of Devastation       66         44           1.0        14
# 14                       Ixalan      102         58           6.0        22
# 15             Journey into Nyx       60         31          21.0        10
# 16                     Kaladesh      105         57           3.0        20
# 17                     Kaldheim      103         55           8.0        24
# 18              Khans of Tarkir       91         49           4.0        19
# 19                   Magic 2014      101         53          11.0        21
# 20                   Magic 2015      105         56          11.0        25
# 21                Magic Origins      107         58           8.0        25
# 22        Oath of the Gatewatch       65         35           3.0        19
# 23           Ravnica Allegiance      102         57           3.0        24
# 24            Return to Ravnica       95         51           8.0        27
# 25             Rivals of Ixalan       71         44           5.0        10
# 26       Shadows over Innistrad      104         54          10.0        19
# 27  Strixhaven: School of Mages       99         49           0.0        25
# 28                       Theros      100         59          16.0        20
# 29          Theros Beyond Death      104         56          33.0        19
# 30           Throne of Eldraine      113         73           5.0        26
# 31             War of the Spark      102         59           3.0        25
# 32              Zendikar Rising      112         67           3.0        24
#
#     Sorcerys  Artifacts
# 0          8       21.0
# 1          9        2.0
# 2         15        1.0
# 3          7        0.0
# 4         13        7.0
# 5         15        6.0
# 6         13       11.0
# 7         10       10.0
# 8         12        5.0
# 9         12        4.0
# 10         8        0.0
# 11        11        6.0
# 12        15        5.0
# 13         5        4.0
# 14        12        5.0
# 15         4        0.0
# 16        14       21.0
# 17        11        6.0
# 18        13        6.0
# 19        16        1.0
# 20        12        4.0
# 21        14        5.0
# 22         6        3.0
# 23        13        5.0
# 24         9        0.0
# 25         9        4.0
# 26        18        4.0
# 27        24        5.0
# 28        10        5.0
# 29         8        5.0
# 30        27       20.0
# 31        13        5.0
# 32        14        7.0

# %%
# for each card type, create a boxplot chart where x is set and y is card ratio

# %% [markdown]
# ## White

# %%
white = pioneer[pioneer['color_identity'].astype(str).str.contains("W")]

# %%
card_type_breakdown_w = white.groupby('set_name').size().reset_index(name = 'commons') # number of commons

card_types = ['Creature', 'Enchantment', 'Instant', 'Sorcery', 'Artifact']
for card_type in card_types:
    new_df = white[white['type_line'].str.contains(card_type)].groupby('set_name').size().reset_index(name = card_type + "s")
    card_type_breakdown_w = card_type_breakdown_w.merge(new_df, how = 'left', on = 'set_name')

print('\nCard Type Breakdown For White\n')
card_type_breakdown_w = card_type_breakdown_w.replace(np.nan, 0).set_index('set_name')
ctypes_ratio_w = card_type_breakdown_w.iloc[:, 1:].div(card_type_breakdown_w.commons, axis = 0)
ratio_sums = [row.Creatures + row.Enchantments + row.Instants + row.Sorcerys + row.Artifacts for index, row in ctypes_ratio_w.iterrows()]
ctypes_ratio_w['ratio_sums'] = ratio_sums
ctypes_ratio_w.head()
# Out:
# Card Type Breakdown For White
#                      Creatures  Enchantments  Instants  Sorcerys  Artifacts  \
# set_name
# Aether Revolt         0.571429      0.142857  0.142857  0.071429   0.142857
# Amonkhet              0.650000      0.100000  0.250000  0.000000   0.000000
# Battle for Zendikar   0.611111      0.055556  0.277778  0.055556   0.000000
# Born of the Gods      0.583333      0.166667  0.166667  0.166667   0.000000
# Core Set 2019         0.666667      0.095238  0.190476  0.047619   0.000000
#
#                      ratio_sums
# set_name
# Aether Revolt          1.071429
# Amonkhet               1.000000
# Battle for Zendikar    1.000000
# Born of the Gods       1.083333
# Core Set 2019          1.000000

# %%
# cart_type_w_long = pd.melt(card_type_breakdown_w, value_vars = ['Creatures', 'Enchantments', 'Instants', 'Sorcerys', 'Artifacts'],  var_name = 'card_type')
# Out:
# 0.6079410458257112

# %% [markdown]
# ### Creatures

# %%
ctypes_ratio_w['Creatures'].mean()
# Out:
# 0.6079410458257112

# %%
white_creatures = white[white['type_line'].str.contains('Creature')]
creature_curve_df_w = white_creatures.groupby(['set_name', 'cmc']).size().reset_index(name = 'cards')
creature_curve_df_w = creature_curve_df_w.groupby('cmc').cards.agg(['mean', 'min', 'max']).reset_index()
plt.bar(x = creature_curve_df_w['cmc'], height = creature_curve_df_w['mean'],
        color = 'white', edgecolor = 'black')
plt.scatter(x = creature_curve_df_w['cmc'], y = creature_curve_df_w['max'])
plt.title('Average Creature Curve')
# Out:
# Text(0.5, 1.0, 'Average Creature Curve')

# %% [markdown]
# ## Blue

# %%
blue = pioneer[pioneer['color_identity'].astype(str).str.contains("U")]
blue_creatures = blue[blue['type_line'].str.contains('Creature')]
blue_creatures
# Out:
#                     name  mana_cost  cmc                       type_line  \
# 3          Siren Lookout     {2}{U}  3.0         Creature — Siren Pirate
# 139      Deep-Sea Terror  {4}{U}{U}  6.0              Creature — Serpent
# 222     Tolarian Scholar     {2}{U}  3.0         Creature — Human Wizard
# 310    Coastline Chimera     {3}{U}  4.0              Creature — Chimera
# 355     Drakewing Krasis  {1}{G}{U}  3.0         Creature — Lizard Drake
# ...                  ...        ...  ...                             ...
# 59446  Metropolis Sprite     {1}{U}  2.0         Creature — Faerie Rogue
# 59576       Scroll Thief     {2}{U}  3.0        Creature — Merfolk Rogue
# 59577    Frost Trickster     {2}{U}  3.0          Creature — Bird Wizard
# 59604   Tattered Haunter     {1}{U}  2.0               Creature — Spirit
# 59783       Aven Eternal     {2}{U}  3.0  Creature — Zombie Bird Warrior
#
#                                              oracle_text power toughness  \
# 3      Flying\nWhen Siren Lookout enters the battlefi...     1         2
# 139    Deep-Sea Terror can't attack unless there are ...     6         6
# 222                                                          2         3
# 310    Flying\n{1}{W}: Coastline Chimera can block an...     1         5
# 355                                      Flying, trample     3         1
# ...                                                  ...   ...       ...
# 59446  Flying\n{U}: Metropolis Sprite gets +1/-1 unti...     1         2
# 59576  Whenever Scroll Thief deals combat damage to a...     1         3
# 59577  Flying\nWhen Frost Trickster enters the battle...     2         2
# 59604  Flying\nTattered Haunter can block only creatu...     2         1
# 59783  Flying\nWhen Aven Eternal enters the battlefie...     2         2
#
#        colors color_identity           keywords  set  \
# 3         [U]            [U]  [Flying, Explore]  xln
# 139       [U]            [U]                 []  ori
# 222       [U]            [U]                 []  dom
# 310       [U]         [U, W]           [Flying]  ths
# 355    [G, U]         [G, U]  [Flying, Trample]  gtc
# ...       ...            ...                ...  ...
# 59446     [U]            [U]           [Flying]  m20
# 59576     [U]            [U]                 []  m14
# 59577     [U]            [U]           [Flying]  stx
# 59604     [U]            [U]           [Flying]  emn
# 59783     [U]            [U]    [Flying, Amass]  war
#
#                           set_name  rarity  edhrec_rank produced_mana  \
# 3                           Ixalan  common       9422.0           NaN
# 139                  Magic Origins  common      16879.0           NaN
# 222                      Dominaria  common      18373.0           NaN
# 310                         Theros  common      18973.0           NaN
# 355                      Gatecrash  common      16024.0           NaN
# ...                            ...     ...          ...           ...
# 59446                Core Set 2020  common      14835.0           NaN
# 59576                   Magic 2014  common       7190.0           NaN
# 59577  Strixhaven: School of Mages  common      15572.0           NaN
# 59604                Eldritch Moon  common      18925.0           NaN
# 59783             War of the Spark  common       8326.0           NaN
#
#       printed_name printed_text  \
# 3              NaN          NaN
# 139            NaN          NaN
# 222            NaN          NaN
# 310            NaN          NaN
# 355            NaN          NaN
# ...            ...          ...
# 59446          NaN          NaN
# 59576          NaN          NaN
# 59577          NaN          NaN
# 59604          NaN          NaN
# 59783          NaN          NaN
#
#                                               legalities lang
# 3      {'standard': 'not_legal', 'future': 'not_legal...   en
# 139    {'standard': 'not_legal', 'future': 'not_legal...   en
# 222    {'standard': 'not_legal', 'future': 'not_legal...   en
# 310    {'standard': 'not_legal', 'future': 'not_legal...   en
# 355    {'standard': 'not_legal', 'future': 'not_legal...   en
# ...                                                  ...  ...
# 59446  {'standard': 'not_legal', 'future': 'not_legal...   en
# 59576  {'standard': 'not_legal', 'future': 'not_legal...   en
# 59577  {'standard': 'legal', 'future': 'legal', 'hist...   en
# 59604  {'standard': 'not_legal', 'future': 'not_legal...   en
# 59783  {'standard': 'not_legal', 'future': 'not_legal...   en
#
# [317 rows x 19 columns]

# %% [markdown]
# ## Black

# %% [markdown]
# ## Red

# %% [markdown]
# ## Green
