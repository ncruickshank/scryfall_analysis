# %% [markdown]
# # Scryfall Analysis - Cube Structure

# %% [markdown]
# __Objective:__ Connect to publicly available data on Scryfall through their REST API to identify patterns set design.

# %%
import datetime
print("Script last ran on", datetime.datetime.today().strftime("%m/%d/%Y"))
# Out:
# Script last ran on 06/01/2021

# %%
# libraries
import pandas as pd
import requests
from selenium import webdriver

# %%
# retrieve the most recent json file containing 'Default Cards'
driver = webdriver.Chrome()
driver.get("https://scryfall.com/docs/api/bulk-data")
all_cards_href = driver.find_element_by_css_selector('#main > div > div.reference-doc-content > div > table:nth-child(7) > tbody > tr:nth-child(5) > td:nth-child(2) > a').get_attribute('href')
all_cards_href

# %%
driver.quit()
df = pd.read_json(all_cards_href)

# %%
print("Shape of df (rows, columns): ", df.shape)
print("Columns Names\n", list(df.columns), "\n")
df.head()
# Out:
# Shape of df (rows, columns):  (60129, 78)
# Columns Names
# ...

# %%
# tidy dataframe
cols = ['name', 'mana_cost', 'cmc', 'type_line', 'oracle_text', 'power', 'toughness', 'colors', 'color_identity', 'keywords', 'set', 'set_name', 'rarity', 'edhrec_rank', 'produced_mana', 'printed_name', 'printed_text']
df[cols]
# Out:
#       object                 name  mana_cost  cmc                   type_line  \
# 0       card          Fury Sliver     {5}{R}  6.0           Creature — Sliver
# 1       card        Kor Outfitter     {W}{W}  2.0      Creature — Kor Soldier
# 2       card               Spirit             0.0     Token Creature — Spirit
# 3       card        Siren Lookout     {2}{U}  3.0     Creature — Siren Pirate
# 4       card                  Web        {G}  1.0          Enchantment — Aura
# ...      ...                  ...        ...  ...                         ...
# 60124   card         Angel's Tomb        {3}  3.0                    Artifact
# 60125   card            Boomerang     {U}{U}  2.0                     Instant
# 60126   card       Celestine Reef             0.0              Plane — Luvion
# 60127   card         Horned Troll     {2}{G}  3.0            Creature — Troll
# 60128   card  Exultant Skymarcher  {1}{W}{W}  3.0  Creature — Vampire Soldier
#
# ...
